# %%
from module_cricket import *

# %%
pd.read_csv('batting_card.csv')
# Out:
#      season  match_id match_name home_team away_team  \
# 0      2022   1298179  ENG v PAK       PAK       ENG
# 1      2022   1298179  ENG v PAK       PAK       ENG
# 2      2022   1298179  ENG v PAK       PAK       ENG
# 3      2022   1298179  ENG v PAK       PAK       ENG
# 4      2022   1298179  ENG v PAK       PAK       ENG
# ..      ...       ...        ...       ...       ...
# 694    2022   1298135   NAM v SL       NAM        SL
# 695    2022   1298135   NAM v SL       NAM        SL
# 696    2022   1298135   NAM v SL       NAM        SL
# 697    2022   1298135   NAM v SL       NAM        SL
# 698    2022   1298135   NAM v SL       NAM        SL
#
#                                         venue       city    country  \
# 0                    Melbourne Cricket Ground  Melbourne  Australia
# 1                    Melbourne Cricket Ground  Melbourne  Australia
# 2                    Melbourne Cricket Ground  Melbourne  Australia
# ...
