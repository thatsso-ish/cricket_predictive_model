# %% [markdown]
# import the module contents

# %%
from module_cricket import *

# %% [markdown]
# load the dataset

# %%
pd.read_csv('NewCricket.csv')
# Out:
#      runs  ballsFaced  minutes  fours  sixes  strikeRate  isNotOut  \
# 0      15          14       24      0      1         107         0
# 1      32          28       58      2      0         114         0
# 2       8          12       15      1      0          66         0
# 3      38          28       46      2      1         135         0
# 4       0           6        8      0      0           0         0
# ..    ...         ...      ...    ...    ...         ...       ...
# 550    29          23       37      2      1         126         0
# 551     4           8        9      0      0          50         0
# 552     5           8       15      0      0          62         0
# 553     0           0        4      0      0           0         0
# 554     8          15       20      0      0          53         0
#
#      runningOver  Wickets  Runnings
# 0            4.2        1        29
# 1           11.1        3        84
# 2            7.1        2        45
# ...

# %% [markdown]
# call a function and assign the model and scaler as parameters

# %%
model = model_cricket('model', 'scaler')
# Out:
# C:\Users\UnpopularUser\anaconda3\lib\site-packages\sklearn\base.py:299: UserWarning: Trying to unpickle estimator LogisticRegression from version 1.3.0 when using version 1.2.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
model.load_and_clean_data('NewCricket.csv')

# %%
model.predicted_outputs()
# Out:
#      runs  ballsFaced  minutes  fours  sixes  strikeRate  runningOver  \
# 0      15          14       24      0      1         107          4.2
# 1      32          28       58      2      0         114         11.1
# 2       8          12       15      1      0          66          7.1
# 3      38          28       46      2      1         135         16.3
# 4       0           6        8      0      0           0         12.2
# ..    ...         ...      ...    ...    ...         ...          ...
# 550    29          23       37      2      1         126         13.6
# 551     4           8        9      0      0          50         12.3
# 552     5           8       15      0      0          62         15.2
# 553     0           0        4      0      0           0         14.2
# 554     8          15       20      0      0          53         18.6
#
#      Wickets  Probability  Prediction
# 0          1     0.003423           0
# 1          3     0.515638           1
# ...

# %%
pddf_new_obs = model.predicted_outputs()

# %% [markdown]
# import the pymysql after installing it

# %%
import pymysql

# %% [markdown]
# create a connecting and cursor then execute

# %%
conn = pymysql.connect(database = 'predicted_outputs', user = 'root', password = '2905')

# %%
cursor = conn.cursor()

# %%
cursor.execute('SELECT * FROM predicted_outputs;')
# Out:
# 555

# %% [markdown]
# inserting data into sql database

# %%
insert_query = 'INSERT INTO predicted_outputs VALUES'

# %%
pddf_new_obs.shape
# Out:
# (555, 10)

# %% [markdown]
# create a loop that will structure your sql query

# %%
for i in range(pddf_new_obs.shape[0]):
    insert_query += '('

    for j in range(pddf_new_obs.shape[1]):
        value = pddf_new_obs.iloc[i, j]
        if isinstance(value, (int, float)):
            insert_query += str(value) + ', '
        else:
            insert_query += f'{value}, '

    insert_query = insert_query[:-2] + '), '

    insert_query = insert_query[:-2] + ';'

# %%
insert_query
# Out:
# 'INSERT INTO predicted_outputs VALUES(15, 14, 24, 0, 1, 107, 4.2, 1, 0.0034232165455892684, 0), (32, 28, 58, 2, 0, 114, 11.1, 3, 0.5156381487375391, 1), (8, 12, 15, 1, 0, 66, 7.1, 2, 0.016174417601037, 0), (38, 28, 46, 2, 1, 135, 16.3, 5, 0.987303816012011, 1), (0, 6, 8, 0, 0, 0, 12.2, 4, 0.4080686781179214, 0), (20, 14, 26, 2, 0, 142, 17.2, 6, 0.9918570406755571, 1), (5, 7, 11, 0, 0, 71, 18.3, 7, 0.9909924821871706, 1), (4, 8, 12, 0, 0, 50, 19.3, 8, 0.9935829364330346, 1), (26, 17, 33, 3, 1, 152, 5.3, 3, 0.011893412480837353, 0), (1, 2, 6, 0, 0, 50, 0.6, 1, 0.0002091484411675752, 0), (10, 9, 16, 2, 0, 111, 3.3, 2, 0.0014494781412094002, 0), (20, 23, 36, 1, 0, 86, 12.3, 4, 0.47583097165915617, 0), (19, 12, 30, 3, 0, 158, 18.2, 5, 0.9971097687798515, 1), (5, 5, 8, 1, 0, 100, 1.4, 1, 0.00037679667360514144, 0), (27, 28, 37, 4, 0, 96, 8.5, 2, 0.03962673020177528, 0), (50, 40, 75, 4, 1, 125, 17.6, 4, 0.9947952946193743, 1), (14, 10, 14, 1, 1, 140, 11.2, 3, 0.4830824124655805, 0), (63, 33
# ...

# %%
cursor.execute(insert_query)
# Out:
# 555

# %% [markdown]
# load the data into sql workbench

# %%
conn.commit()

# %%
conn.close()

# %% [markdown]
# LinkedIn Ismael (Ishmael T.) Ngobeni
